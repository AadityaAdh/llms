# %% [markdown]
# <a href="https://colab.research.google.com/github/AadityaAdh/llms/blob/main/bigram_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
about_me="Aaditya Adhikari is a dedicated computer engineering graduate from Khwopa Engineering College, where they maintained a strong academic record . With a genuine enthusiasm for learning and growth, Aaditya explores various resources and methodologies to enhance their knowledge, often implementing new insights in coding and real-life applications alike. They have experience across a range of technologies and projects that showcase both technical and creative skills. Aaditya has developed applications in web development, including a traffic sign recognition and generation project using DCGAN, an airline reservation system using HTML, CSS, JavaScript, and PHP, as well as a virtual try-on system powered by a pix2pix GAN model that transforms clothing masks into realistic, wearable images. This try-on system involved intricate work with segmentation models, mask generation, and a dataset prepared specifically for training their GAN model.Aaditya's expertise is also reflected in their proficiency with TensorFlow, where they have worked on advanced models such as a face recognition system that integrates both classification and bounding box prediction functionalities. They have demonstrated an ability to optimize GAN models, improving the quality of generated images through various tuning techniques and processing methods. Additionally, Aaditya has hands-on experience in data analysis and machine learning, having worked on clustering algorithms like K-means for a football players clustering project and a Naïve Bayes classifier applied to the Titanic dataset. Beyond technical projects, Aaditya is proactive in sharing knowledge, as evidenced by their YouTube video on developing an automated attendance system with facial recognition, which aligns with their extensive work in this field.Furthermore, Aaditya’s web development skills include proficiency in Flask, Streamlit, and the implementation of interactive web components. For instance, they have designed a user-friendly interface in their Flask app, ensuring sections fit within a single screen and styling key areas as interactive buttons to enhance usability. Aaditya’s approach to problem-solving is marked by a preference for making precise adjustments to their code, valuing incremental corrections over complete rewrites to maintain consistency and clarity in their projects. They have also applied advanced concepts in data handling within Excel, familiarizing themselves with functions like SUMIF and SUMIFS to perform conditional data analysis efficiently. As Aaditya steps into the professional world, they aspire to apply their skills in a role that merges data analysis and Python development, with a keen interest in securing a position at Deerhold. With a robust foundation in computer engineering, a practical and creative project portfolio, and a willingness to continuously learn and improve, Aaditya is well-prepared for future challenges in the tech industry."

# %%
unique_words=set(about_me.split())
unique_words
# Out:
# {'.',
#  'Aaditya',
#  'Aaditya’s',
#  'Additionally,',
#  'Adhikari',
#  'As',
#  'Bayes',
#  'Beyond',
#  'CSS,',
#  'College,',
#  'DCGAN,',
#  'Deerhold.',
#  'Engineering',
#  'Excel,',
#  'Flask',
#  'Flask,',
#  'For',
#  'GAN',
#  'HTML,',
#  'JavaScript,',
#  'K-means',
#  'Khwopa',
#  'Naïve',
#  'PHP,',
#  'Python',
#  'SUMIF',
#  'SUMIFS',
#  'Streamlit,',
#  'TensorFlow,',
#  'They',
#  'This',
#  'Titanic',
#  'With',
#  'YouTube',
#  'a',
#  'ability',
#  'academic',
#  'across',
#  'adjustments',
#  'advanced',
#  'airline',
#  'algorithms',
#  'aligns',
#  'alike.',
#  'also',
#  'an',
#  'analysis',
#  'and',
#  'app,',
#  'applications',
#  'applied',
#  'apply',
#  'approach',
#  'areas',
#  'as',
#  'aspire',
#  'at',
#  'attendance',
#  'automated',
#  'both',
#  'bounding',
#  'box',
#  'buttons',
#  'by',
#  'challenges',
#  'clarity',
#  'classification',
#  'classifier',
#  'clothing',
#  'clustering',
#  'code,',
#  'coding',
#  'complete',
# ...

# %%
unique_words_count_dict={elements:0 for elements in unique_words}
unique_words_count_dict
# Out:
# {'corrections': 0,
#  'knowledge,': 0,
#  'functionalities.': 0,
#  'preference': 0,
#  'as': 0,
#  'expertise': 0,
#  'PHP,': 0,
#  'Aaditya': 0,
#  'challenges': 0,
#  'such': 0,
#  'developing': 0,
#  'technical': 0,
#  'aligns': 0,
#  'designed': 0,
#  'making': 0,
#  'new': 0,
#  'skills.': 0,
#  'areas': 0,
#  'sharing': 0,
#  'dataset': 0,
#  'fit': 0,
#  'specifically': 0,
#  'players': 0,
#  'usability.': 0,
#  'code,': 0,
#  'handling': 0,
#  'As': 0,
#  'of': 0,
#  'that': 0,
#  'tech': 0,
#  'video': 0,
#  'at': 0,
#  'enthusiasm': 0,
#  'implementing': 0,
#  'For': 0,
#  'creative': 0,
#  'reservation': 0,
#  'Aaditya’s': 0,
#  'SUMIFS': 0,
#  'face': 0,
#  'maintained': 0,
#  'functions': 0,
#  'facial': 0,
#  'using': 0,
#  'Additionally,': 0,
#  'through': 0,
#  'for': 0,
#  'complete': 0,
#  'projects': 0,
#  'generation': 0,
#  'images.': 0,
#  'recognition': 0,
#  'methods.': 0,
#  'future': 0,
#  'classifier': 0,
#  'training': 0,
#  'reflected': 0,
# ...

# %%
for elements in about_me.split():
  unique_words_count_dict[elements]+=1
unique_words_count_dict
# Out:
# {'corrections': 1,
#  'knowledge,': 2,
#  'functionalities.': 1,
#  'preference': 1,
#  'as': 5,
#  'expertise': 1,
#  'PHP,': 1,
#  'Aaditya': 7,
#  'challenges': 1,
#  'such': 1,
#  'developing': 1,
#  'technical': 2,
#  'aligns': 1,
#  'designed': 1,
#  'making': 1,
#  'new': 1,
#  'skills.': 1,
#  'areas': 1,
#  'sharing': 1,
#  'dataset': 1,
#  'fit': 1,
#  'specifically': 1,
#  'players': 1,
#  'usability.': 1,
#  'code,': 1,
#  'handling': 1,
#  'As': 1,
#  'of': 3,
#  'that': 4,
#  'tech': 1,
#  'video': 1,
#  'at': 1,
#  'enthusiasm': 1,
#  'implementing': 1,
#  'For': 1,
#  'creative': 2,
#  'reservation': 1,
#  'Aaditya’s': 2,
#  'SUMIFS': 1,
#  'face': 1,
#  'maintained': 1,
#  'functions': 1,
#  'facial': 1,
#  'using': 2,
#  'Additionally,': 1,
#  'through': 1,
#  'for': 5,
#  'complete': 1,
#  'projects': 1,
#  'generation': 1,
#  'images.': 1,
#  'recognition': 2,
#  'methods.': 1,
#  'future': 1,
#  'classifier': 1,
#  'training': 1,
#  'reflected': 1,
# ...

# %%
temp=about_me.split()
biagram_words={temp[i]:{temp[i+1]:0} for i,initial in enumerate(temp) if i!=len(temp)-1}
biagram_words

# yo mildaina as tyo key ma append garnu sato tyo key ko value chai replace vai ranxa
# Out:
# {'Aaditya': {'is': 0},
#  'Adhikari': {'is': 0},
#  'is': {'well-prepared': 0},
#  'a': {'willingness': 0},
#  'dedicated': {'computer': 0},
#  'computer': {'engineering,': 0},
#  'engineering': {'graduate': 0},
#  'graduate': {'from': 0},
#  'from': {'Khwopa': 0},
#  'Khwopa': {'Engineering': 0},
#  'Engineering': {'College,': 0},
#  'College,': {'where': 0},
#  'where': {'they': 0},
#  'they': {'aspire': 0},
#  'maintained': {'a': 0},
#  'strong': {'academic': 0},
#  'academic': {'record': 0},
#  'record': {'.': 0},
#  '.': {'With': 0},
#  'With': {'a': 0},
#  'genuine': {'enthusiasm': 0},
#  'enthusiasm': {'for': 0},
#  'for': {'future': 0},
#  'learning': {'and': 0},
#  'and': {'improve,': 0},
#  'growth,': {'Aaditya': 0},
#  'explores': {'various': 0},
#  'various': {'tuning': 0},
#  'resources': {'and': 0},
#  'methodologies': {'to': 0},
#  'to': {'continuously': 0},
#  'enhance': {'usability.': 0},
#  'their': {'skills': 0},
#  'knowledge,': {'as': 0},
# ...

# %%
biagram_words=[(temp[i],temp[i+1]) for i,elements in enumerate(temp) if i!=len(temp)-1]
set(biagram_words)
# Out:
# {('.', 'With'),
#  ('Aaditya', 'Adhikari'),
#  ('Aaditya', 'explores'),
#  ('Aaditya', 'has'),
#  ('Aaditya', 'is'),
#  ('Aaditya', 'steps'),
#  ('Aaditya’s', 'approach'),
#  ('Aaditya’s', 'web'),
#  ('Additionally,', 'Aaditya'),
#  ('Adhikari', 'is'),
#  ('As', 'Aaditya'),
#  ('Bayes', 'classifier'),
#  ('Beyond', 'technical'),
#  ('CSS,', 'JavaScript,'),
#  ('College,', 'where'),
#  ('DCGAN,', 'an'),
#  ('Deerhold.', 'With'),
#  ('Engineering', 'College,'),
#  ('Excel,', 'familiarizing'),
#  ('Flask', 'app,'),
#  ('Flask,', 'Streamlit,'),
#  ('For', 'instance,'),
#  ('GAN', 'model'),
#  ('GAN', "model.Aaditya's"),
#  ('GAN', 'models,'),
#  ('HTML,', 'CSS,'),
#  ('JavaScript,', 'and'),
#  ('K-means', 'for'),
#  ('Khwopa', 'Engineering'),
#  ('Naïve', 'Bayes'),
#  ('PHP,', 'as'),
#  ('Python', 'development,'),
#  ('SUMIF', 'and'),
#  ('SUMIFS', 'to'),
#  ('Streamlit,', 'and'),
#  ('TensorFlow,', 'where'),
#  ('They', 'have'),
#  ('This', 'try-on'),
#  ('Titanic', 'dataset.'),
# ...

# %%
biagram_words_count_dict={my_tuple:0 for my_tuple in biagram_words}
biagram_words_count_dict
# Out:
# {('Aaditya', 'Adhikari'): 0,
#  ('Adhikari', 'is'): 0,
#  ('is', 'a'): 0,
#  ('a', 'dedicated'): 0,
#  ('dedicated', 'computer'): 0,
#  ('computer', 'engineering'): 0,
#  ('engineering', 'graduate'): 0,
#  ('graduate', 'from'): 0,
#  ('from', 'Khwopa'): 0,
#  ('Khwopa', 'Engineering'): 0,
#  ('Engineering', 'College,'): 0,
#  ('College,', 'where'): 0,
#  ('where', 'they'): 0,
#  ('they', 'maintained'): 0,
#  ('maintained', 'a'): 0,
#  ('a', 'strong'): 0,
#  ('strong', 'academic'): 0,
#  ('academic', 'record'): 0,
#  ('record', '.'): 0,
#  ('.', 'With'): 0,
#  ('With', 'a'): 0,
#  ('a', 'genuine'): 0,
#  ('genuine', 'enthusiasm'): 0,
#  ('enthusiasm', 'for'): 0,
#  ('for', 'learning'): 0,
#  ('learning', 'and'): 0,
#  ('and', 'growth,'): 0,
#  ('growth,', 'Aaditya'): 0,
#  ('Aaditya', 'explores'): 0,
#  ('explores', 'various'): 0,
#  ('various', 'resources'): 0,
#  ('resources', 'and'): 0,
#  ('and', 'methodologies'): 0,
#  ('methodologies', 'to'): 0,
#  ('to', 'enhance'): 0,
# ...

# %%
for i,words in enumerate(temp):
  if i!=len(temp)-1:
    biagram_words_count_dict[(temp[i],temp[i+1])]+=1

biagram_words_count_dict
# Out:
# {('Aaditya', 'Adhikari'): 1,
#  ('Adhikari', 'is'): 1,
#  ('is', 'a'): 1,
#  ('a', 'dedicated'): 1,
#  ('dedicated', 'computer'): 1,
#  ('computer', 'engineering'): 1,
#  ('engineering', 'graduate'): 1,
#  ('graduate', 'from'): 1,
#  ('from', 'Khwopa'): 1,
#  ('Khwopa', 'Engineering'): 1,
#  ('Engineering', 'College,'): 1,
#  ('College,', 'where'): 1,
#  ('where', 'they'): 2,
#  ('they', 'maintained'): 1,
#  ('maintained', 'a'): 1,
#  ('a', 'strong'): 1,
#  ('strong', 'academic'): 1,
#  ('academic', 'record'): 1,
#  ('record', '.'): 1,
#  ('.', 'With'): 1,
#  ('With', 'a'): 2,
#  ('a', 'genuine'): 1,
#  ('genuine', 'enthusiasm'): 1,
#  ('enthusiasm', 'for'): 1,
#  ('for', 'learning'): 1,
#  ('learning', 'and'): 1,
#  ('and', 'growth,'): 1,
#  ('growth,', 'Aaditya'): 1,
#  ('Aaditya', 'explores'): 1,
#  ('explores', 'various'): 1,
#  ('various', 'resources'): 1,
#  ('resources', 'and'): 1,
#  ('and', 'methodologies'): 1,
#  ('methodologies', 'to'): 1,
#  ('to', 'enhance'): 2,
# ...

# %%
for i,words in enumerate(temp):
  if i!=len(temp)-1:
    print(words)
    print(temp[i+1])
    print(biagram_words_count_dict[(words,temp[i+1])])
    print(unique_words_count_dict[words])
    biagram_words_count_dict[(words,temp[i+1])]= biagram_words_count_dict[(words,temp[i+1])]/unique_words_count_dict[words]
# Out:
# Aaditya
# Adhikari
# 1
# 7
# Adhikari
# is
# 1
# 1
# is
# a
# 1
# 5
# a
# dedicated
# 1
# 20
# dedicated
# computer
# 1
# 1
# computer
# engineering
# 1
# 2
# engineering
# graduate
# 1
# 1
# graduate
# from
# 1
# 1
# from
# Khwopa
# 1
# 1
# Khwopa
# Engineering
# 1
# 1
# Engineering
# College,
# 1
# 1
# College,
# where
# 1
# 1
# where
# they
# 2
# 2
# they
# maintained
# 1
# 4
# maintained
# a
# 1
# 1
# a
# strong
# 1
# 20
# strong
# academic
# 1
# 1
# academic
# record
# 1
# 1
# record
# .
# 1
# 1
# .
# With
# 1
# 1
# With
# a
# 2
# 2
# a
# genuine
# 1
# 20
# genuine
# enthusiasm
# 1
# 1
# enthusiasm
# for
# 1
# 1
# for
# learning
# 1
# 5
# learning
# and
# 1
# 1
# and
# growth,
# 1
# 20
# growth,
# Aaditya
# 1
# 1
# Aaditya
# explores
# 1
# 7
# explores
# various
# 1
# 1
# various
# resources
# 1
# 2
# resources
# and
# 1
# 1
# and
# methodologies
# 1
# 20
# methodologies
# to
# 1
# 1
# to
# enhance
# 2
# 10
# enhance
# their
# 1
# 2
# their
# knowledge,
# 1
# 9
# knowledge,
# ...

# %%
biagram_words_count_dict
# Out:
# {('Aaditya', 'Adhikari'): 0.14285714285714285,
#  ('Adhikari', 'is'): 1.0,
#  ('is', 'a'): 0.2,
#  ('a', 'dedicated'): 0.05,
#  ('dedicated', 'computer'): 1.0,
#  ('computer', 'engineering'): 0.5,
#  ('engineering', 'graduate'): 1.0,
#  ('graduate', 'from'): 1.0,
#  ('from', 'Khwopa'): 1.0,
#  ('Khwopa', 'Engineering'): 1.0,
#  ('Engineering', 'College,'): 1.0,
#  ('College,', 'where'): 1.0,
#  ('where', 'they'): 0.5,
#  ('they', 'maintained'): 0.25,
#  ('maintained', 'a'): 1.0,
#  ('a', 'strong'): 0.05,
#  ('strong', 'academic'): 1.0,
#  ('academic', 'record'): 1.0,
#  ('record', '.'): 1.0,
#  ('.', 'With'): 1.0,
#  ('With', 'a'): 0.5,
#  ('a', 'genuine'): 0.05,
#  ('genuine', 'enthusiasm'): 1.0,
#  ('enthusiasm', 'for'): 1.0,
#  ('for', 'learning'): 0.2,
#  ('learning', 'and'): 1.0,
#  ('and', 'growth,'): 0.05,
#  ('growth,', 'Aaditya'): 1.0,
#  ('Aaditya', 'explores'): 0.14285714285714285,
#  ('explores', 'various'): 1.0,
#  ('various', 'resources'): 0.5,
# ...

# %%
class Biagrammodel():
  def __init__(self):
    pass
  def predict(self,initialword,num_words,biagram_words_count_dict,temp):

    prevword=initialword
    print(prevword)
    for j in range(num_words):
      prob_values=[biagram_words_count_dict[(prevword,temp[i+1])] for i,element in enumerate(temp) if element==prevword and i!=len(temp)-1]
      highest_prob=np.max(prob_values)
      for i,element in enumerate(temp):
        if element==prevword and i!=len(temp)-1 and biagram_words_count_dict[(prevword,temp[i+1])]==highest_prob:

          print(temp[i+1])
          prevword=temp[i+1]

# %%
obj1=Biagrammodel()

# %%
obj1.predict('Aaditya',10,biagram_words_count_dict,temp)
# Out:
# Aaditya
# Adhikari
# is
# a
# dedicated
# computer
# engineering
# graduate
# from
# Khwopa
# Engineering
# College,
# where
# they
# maintained
# a

# %%
obj1.predict('applied',10,biagram_words_count_dict,temp)
# Out:
# applied
# to
# optimize
# GAN
# model
# that
# showcase
# both
# technical
# and
# growth,
# Aaditya

# %%
obj1.predict('automated',10,biagram_words_count_dict,temp)
# Out:
# automated
# attendance
# system
# using
# DCGAN,
# an
# airline
# reservation
# system
# using
# DCGAN,
# an
# airline
